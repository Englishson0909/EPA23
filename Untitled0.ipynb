# %% [markdown]
# <a href="https://colab.research.google.com/github/Englishson0909/EPA23/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Today's new markdown

# %%
#@markdown Install and import libraries
# %%capture
# !pip install gtts
from gtts import gTTS
from IPython.display import Audio, display
import pandas as pd

# %%
#@markdown Define ktts(), etts()
def etts(txt):
  tts = gTTS(txt, lang='en')
  tts.save("E-audio.mp3")
  return Audio("/content/E-audio.mp3")

def ktts(txt):
  tts = gTTS(txt, lang='ko')
  tts.save("K-audio.mp3")
  return Audio("/content/K-audio.mp3")

# %%
#@markdown Read csv file
url = "https://raw.githubusercontent.com/MK316/workspace/main/ASR01/data/rainbow_bysentence.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    SN                                           Sentence
# 0  S1  When the sunlight strikes raindrops in the air...
# 1  S2  The rainbow is a division of white light into ...
# 2  S3  These take the shape of a long round arch, wit...
# 3  S4  There is, according to legend, a boiling pot o...
# 4  S5             People look, but no one ever finds it.

# %%
etts("The rainbow is a division of white light into ")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
etts("I like this class")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
etts("when the sunlight strikes raindrops")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
etts (" I was under the rock, but now I am getting out of it")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
etts("Hi, My name is Jeeny from Canada. I am helping you speak English. Whenever you have a question, please ask me")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Trial
