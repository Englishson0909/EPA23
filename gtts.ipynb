# %% [markdown]
# <a href="https://colab.research.google.com/github/Englishson0909/EPA23/blob/main/gtts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@markdown 1) Install and import modules
# %%capture
# !pip install gtts
from gtts import gTTS
from IPython.display import Audio, display

# %%
#@markdown 2) Define tts(text)

def tts(txt):
  tts = gTTS(txt, lang='en')
  tts.save("sample.mp3")
  return Audio("/content/sample.mp3")

# %%
#@markdown 3) Getting audio and display

mytext = input("Type text: ")
tts(mytext)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-f01036644eff> in <cell line: 3>()
#       1 #@markdown 3) Getting audio and display
#       2
# ----> 3 mytext = input("Type text: ")
#       4 tts(mytext)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
#@markdown Q1: "Why do teachers need to teach pronunication?"

mytext = "Clear and accurate pronunciation is essential for effective communication in any language."
tts(mytext)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown Q2: "What is the most biggest challenge when teaching pronunication?"

mytext = "The native language of a learner can heavily influence their pronunciation in the target language, leading to what is commonly known as accent. Certain sounds, intonations, or stress patterns that are present in the learner's native language may not exist or may differ in the target language."
print(mytext)
tts(mytext)
# Out:
# The native language of a learner can heavily influence their pronunciation in the target language, leading to what is commonly known as accent. Certain sounds, intonations, or stress patterns that are present in the learner's native language may not exist or may differ in the target language.
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown Q3: "Good tools for practicing pronunicaiton based on AI"

mytext = "Elsa Speak, Pronunciation Power, Speechling, Pronunciator, Lingvist, Rosetta Stone"
print(mytext)
tts(mytext)
# Out:
# Elsa Speak, Pronunciation Power, Speechling, Pronunciator, Lingvist, Rosetta Stone
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown Install and import libraries {gtts},{Audio}
# !pip install gtts
from gtts import gTTS
from IPython.display import Audio, display

def tts(txt):
  tts = gTTS(txt, lang='en', tld="us")
  tts.save("sample.mp3")
  return Audio("/content/sample.mp3")

# %%
#@markdown Test: audio

text = "I can't bear to hear the bear growl ."
tts(text)
Audio("sample.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
